# %%
#Q1.

# %% [markdown]
# [Distribution Dimensionality](https://www.pymc.io/projects/docs/en/stable/learn/core_notebooks/dimensionality.html#dimensionality)
# [PyMC and PyTensor](https://www.pymc.io/projects/docs/en/stable/learn/core_notebooks/pymc_pytensor.html)
# [Using Data Containers](https://www.pymc.io/projects/examples/en/latest/fundamentals/data_container.html)
#
# ![Distribution Dimensionality](https://www.pymc.io/projects/docs/en/stable/_images/acfb0536de4db53baddb8a6d632d6efdc65c01eedeee1a90b7b1e1dd45db4c16.svg)
# ![PyMC and PyTensor](https://raw.githubusercontent.com/pymc-devs/pytensor/main/doc/tutorial/apply.png)
# ![Using Data Containers](https://www.pymc.io/projects/examples/en/latest/_images/e84fba8908ce2dbfc366050d8853911d674afeffc281841f8609691a3f218599.svg)

# %% [markdown]
# [1.How to-model comparison](https://www.pymc.io/projects/docs/en/stable/learn/core_notebooks/model_comparison.html#model-comparison)
# ![](https://www.pymc.io/projects/docs/en/stable/_images/220695e8447f0651dc133a3389ef5d6f586b78e08421f0a2371928118cc909f1.png)

# %% [markdown]
# [2. Generalized Linear Models-Binomial regression](https://www.pymc.io/projects/examples/en/latest/generalized_linear_models/GLM-binomial-regression.html)
# ![](https://www.pymc.io/projects/examples/en/latest/_images/2af54aa3c6d0dcc893750608896f94dc41d623fee75756f05e3e97b629e9718a.png)

# %% [markdown]
# [3. Case Studies-Hierarchical Partial Pooling](https://www.pymc.io/projects/examples/en/latest/case_studies/hierarchical_partial_pooling.html)
# ![](https://www.pymc.io/projects/examples/en/latest/_images/ebc23400283c5ac276dcac1cb83402a474a679bf3963131b9f20349b2c052dea.svg)

# %% [markdown]
# [4.Causal Inference-Bayesian mediation analysis](https://www.pymc.io/projects/examples/en/latest/causal_inference/mediation_analysis.html)
# ![](https://www.pymc.io/projects/examples/en/latest/_images/2a4466f8eae2f01cc0a4618fddb31613803b591dcfbb983b38743a7c7ac3e45e.png)

# %% [markdown]
# [5.Gaussian Processes-Student-t Process](https://www.pymc.io/projects/examples/en/latest/gaussian_processes/GP-TProcess.html)
# ![](https://www.pymc.io/projects/examples/en/latest/_images/d2259dbccd843cf921d8959d7935b2dea30c5e4bc73e0c4dd5a237ce6c12b49d.png)

# %% [markdown]
# [6.Time Series-Stochastic Volatility model](https://www.pymc.io/projects/examples/en/latest/time_series/stochastic_volatility.html)
# ![](https://www.pymc.io/projects/examples/en/latest/_images/aeebe9a8f6940b18037893475f734ba281c80d30ac54248fa63914f9fc3afda0.png)

# %% [markdown]
# [7. Spatial Analysis-The Besag-York-Mollie Model for Spatial Data](https://www.pymc.io/projects/examples/en/latest/spatial/nyc_bym.html)
# ![](https://www.pymc.io/projects/examples/en/latest/_images/9e90708d64b17b75736c36089b5e622a76dd48f5be82a2f4de7f457d964f18dc.png)

# %% [markdown]
# [8. Diagnostics and Model Criticism-Diagnosing Biased Inference with Divergences](https://www.pymc.io/projects/examples/en/latest/diagnostics_and_criticism/Diagnosing_biased_Inference_with_Divergences.html)
# ![](https://www.pymc.io/projects/examples/en/latest/diagnostics_and_criticism/Diagnosing_biased_Inference_with_Divergences.html)

# %% [markdown]
# [9. Bayesian Additive Regression Trees-Quantile Regression with BART](https://www.pymc.io/projects/examples/en/latest/bart/bart_quantile_regression.html)
# ![](https://www.pymc.io/projects/examples/en/latest/_images/db057b16cc6507be0bf4e84b884be162f7f37c6622887347e3b616418e3b79fe.png)

# %% [markdown]
# [10. Mixture Models-Gaussian Mixture Model](https://www.pymc.io/projects/examples/en/latest/mixture_models/gaussian_mixture_model.html)
# ![](https://www.pymc.io/projects/examples/en/latest/_images/012f9879fa47ef8c3b5e07ce603bda73e12e36c99842002efbd74094d1b5beff.png)

# %% [markdown]
# [11. Survival Analysis-Frailty and Survival Regression Models](https://www.pymc.io/projects/examples/en/latest/survival_analysis/frailty_models.html)
# ![](https://www.pymc.io/projects/examples/en/latest/_images/0757f1a5b6a82d449911b653f89cad6cfbdbf8ae404337f35ce0c04ed4b709ec.png)

# %% [markdown]
# [12. ODE models-ODE Lotka-Volterra With Bayesian Inference in Multiple Ways](https://www.pymc.io/projects/examples/en/latest/ode_models/ODE_Lotka_Volterra_multiple_ways.html)
# ![](https://www.pymc.io/projects/examples/en/latest/_images/07e77a972517df91ac84d870e9b2c42ca3c9f6f92420d84a4ef85ff0eb59d895.png)

# %% [markdown]
# [13. MCMC-Lasso regression with block updating
# %matplotlib inline](https://www.pymc.io/projects/examples/en/latest/samplers/lasso_block_update.html)
# ![](https://www.pymc.io/projects/examples/en/latest/_images/2bc755fd8bf0a29be0c099502d53d2097de89708e8fd4c792426392f28773e1f.png)

# %% [markdown]
# [14. Variational Inference-Pathfinder Variational Inference](https://www.pymc.io/projects/examples/en/latest/variational_inference/pathfinder.html)
# ![](https://www.pymc.io/projects/examples/en/latest/_images/077012558f2fe2e6b21854e6182b00e824a0d3a00e6df1688d13d20081a76027.png)

# %%
#Q2.

import pymc as pm
import numpy as np
import arviz as az
import matplotlib.pyplot as plt

n = 100
true_theta = 3
true_tau = 5
observed_data = np.random.normal(loc=true_theta, scale=1/np.sqrt(true_tau), size=n)

# PyMC Model
with pm.Model() as model_1:
    # Priors
    theta = pm.Normal("theta", mu=0, sigma=1)  # Normal prior
    tau = pm.Gamma("tau", alpha=2, beta=2)  # Gamma prior

    # Likelihood
    x_obs = pm.Normal("x_obs", mu=theta, sigma=1/pm.math.sqrt(tau), observed=observed_data)

    # Inference
    trace_1 = pm.sample(2000, return_inferencedata=True)

# Diagnostic plots
az.plot_trace(trace_1)
plt.show()

# Summary statistics
az.summary(trace_1, round_to=5)
# Out:
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
#           mean       sd   hdi_3%  hdi_97%  mcse_mean  mcse_sd    ess_bulk  \
# tau    4.07863  0.57308  3.05526  5.16202    0.00877  0.00625  4239.75108
# theta  2.96792  0.04989  2.87254  3.05997    0.00078  0.00055  4152.01389
#
#          ess_tail    r_hat
# tau    2783.95197  0.99984
# theta  2827.28232  1.00077

# %%
n = 100
true_theta = 3
true_tau = 5
observed_data = np.random.normal(loc=true_theta, scale=1/np.sqrt(true_tau), size=n)

with pm.Model() as model_2:
    theta = pm.StudentT("theta", nu=3, mu=0, sigma=1)  # Non-normal prior
    tau = pm.HalfCauchy("tau", beta=2)  # Non-gamma prior

    x_obs = pm.Normal("x_obs", mu=theta, sigma=1/pm.math.sqrt(tau), observed=observed_data)

    trace_2 = pm.sample(2000, return_inferencedata=True)

az.plot_trace(trace_2)
plt.show()

az.summary(trace_2, round_to=5)
# Out:
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
#           mean       sd   hdi_3%  hdi_97%  mcse_mean  mcse_sd    ess_bulk  \
# tau    7.20961  1.04576  5.30050  9.21005    0.01737  0.01245  3642.23611
# theta  3.11277  0.03740  3.04192  3.18126    0.00059  0.00042  4006.29483
#
#          ess_tail    r_hat
# tau    2624.16984  1.00042
# theta  2565.90702  1.00037

# %%
n = 100
true_theta = 3
true_tau = 5
observed_data = np.random.normal(loc=true_theta, scale=1/np.sqrt(true_tau), size=n)

with pm.Model() as model_3:
    theta = pm.Laplace("theta", mu=0, b=1)  # Different non-normal prior
    tau = pm.Exponential("tau", lam=1)  # Different non-gamma prior

    x_obs = pm.Normal("x_obs", mu=theta, sigma=1/pm.math.sqrt(tau), observed=observed_data)

    trace_3 = pm.sample(2000, return_inferencedata=True)

az.plot_trace(trace_3)
plt.show()

az.summary(trace_3, round_to=5)
# Out:
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
#           mean       sd   hdi_3%  hdi_97%  mcse_mean  mcse_sd    ess_bulk  \
# tau    4.88745  0.67023  3.65476  6.12225    0.01075  0.00763  3866.46001
# theta  3.04918  0.04569  2.96380  3.13661    0.00072  0.00051  4014.00143
#
#          ess_tail    r_hat
# tau    3152.60832  0.99997
# theta  2771.63884  1.00041

# %%
#Q3.
def slice_f_at_y(f, x, y, x_grid=np.linspace(0,1,51)):

    # find interval of grid points where f(x_grid) > y
    # then extend the enterval so endpoints f(a)<y and f(b)<y
    x_grid_delta = x_grid[1]-x_grid[0]
    a,b = x_grid[f(x_grid)>y][[0,-1]]+[-x_grid_delta,x_grid_delta]
    # a,b = x_grid[0,-1]  # make the interval all of x_grid

    x_ = a + stats.uniform().rvs()*(b-a)
    if f(x_)>y:
        return x_,1  # in 1 try if f(x_)>y and "x_ is under f"
    elif x_ < x:  # or if "x_ was above f on the left side of the interval"
        x_l,x_r = x_,b
    else:
        x_l,x_r = a,x_  # or if "x_ was above f on the right side of the interval"
    return slice_f_at_y_(f, x, y, x_l, x_r, tot = 2)  # try again with a reduced interval

def slice_f_at_y_(f, x, y, x_l=0, x_r=1, tot=1):

    x_ = x_l + stats.uniform().rvs()*(x_r-x_l)

    if f(x_)>y:
        return x_,tot
    elif x_ < x:
        x_l = x_
    else:
        x_r = x_
    return slice_f_at_y_(f, x, y, x_l, x_r, tot = tot+1)

# %%
from scipy import stats

x_grid = np.linspace(0,1,1000)
f = lambda x: stats.beta(1.5,3).pdf(x)
plt.plot(x_grid, f(x_grid))

m = 1000
x = np.zeros([m+1,3])
x[:2,0] = 0.25

plot_trace = 10
for t in range(1,m):

    x[t,1] = stats.uniform().rvs()*f(x[t,0])
    if t < plot_trace:
        plt.plot([x[t,0]]*2, [x[t-1,1],x[t,1]], 'k')

    x[t+1,0],x[t+1,2] = slice_f_at_y(f, x[t,0], x[t,1])
    if t < plot_trace:
        if t==1:
            plt.plot([x[t,0], x[t+1,0]], [x[t,1]]*2, 'k--', label=str(plot_trace)+ " iterations")
        plt.plot([x[t,0], x[t+1,0]], [x[t,1]]*2, 'k--')

plt.hist(x[:,0], density=True, label=str(m)+" iterations\n x values only")
plt.legend();

# %%
#Answer for this question will be written in another file uploaded to the same repo
